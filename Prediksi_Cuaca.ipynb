# %% [markdown]
# <a href="https://colab.research.google.com/github/RomadonaTanjungAT/Prediksi_Cuaca_PT_GGP/blob/main/Prediksi_Cuaca.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import library
import pandas as pd
import numpy as np
from numpy import array
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.model_selection import train_test_split #untuk membagi data
from keras.preprocessing.sequence import TimeseriesGenerator
import tensorflow as tf
from tensorflow.keras import optimizers
from sklearn.metrics import mean_squared_error,  mean_absolute_error, mean_absolute_percentage_error
from keras.models import Sequential
from keras.layers import LSTM, Dense, RepeatVector, TimeDistributed, Dropout

#import data
data = pd.read_excel('/content/data cuaca harian GGP.xlsx') #memanggil data
df = pd.DataFrame(data) #mengubah data menjadi bentuk data frame
df_time = df["tanggal"]
df = df.drop(['tanggal'],axis=1)
df = df.drop(['WD'],axis=1)
print(df)
# Out:
#        RF     SM     ST   SEC    BLT    WS       AP     AT     AH   UV
# 0     0.0  25.51  28.70  31.0  24.08  0.00  1007.10  24.00  94.92  0.0
# 1     0.0  25.58  28.50  31.0  23.99  0.00  1006.30  23.60  94.92  0.0
# 2     0.0  25.66  28.38  31.0  23.92  0.00  1005.80  23.80  94.92  0.0
# 3     0.0  25.54  28.23  32.0  23.74  0.04  1005.58  23.60  94.92  0.0
# 4     0.0  25.54  28.16  31.0  24.11  0.11  1005.60  23.76  94.92  0.0
# ...   ...    ...    ...   ...    ...   ...      ...    ...    ...  ...
# 5827  0.0  26.94  29.50  79.0  26.30  1.03  1009.80  26.18  93.00  0.0
# 5828  0.0  26.98  29.46  79.0  25.00  0.08  1010.70  25.10  94.92  0.0
# 5829  0.0  26.89  29.40  79.0  24.48  0.07  1011.50  24.10  94.92  0.0
# 5830  0.0  26.94  29.30  80.0  23.92  0.03  1011.70  23.70  94.92  0.0
# 5831  0.0  26.88  29.21  79.0  23.73  0.08  1011.76  23.30  94.92  0.0
#
# [5832 rows x 10 columns]

# %%
parameter = ['RF','SM','ST','SEC','BLT','WS','AP','AT','AH','UV']
for i in parameter :
  mean = df[i].mean()
  df[i] = df[i].replace(np.nan, mean)

#menyimpan data
data_fix = df
data_fix.to_excel('data harian menggunakan mean.xlsx', index=False)

indicator = ['RF','SM','ST','SEC','BLT','WS','AP','AT','AH','UV']
df = df[indicator]

# %%
def split_sequences(sequences, n_steps_in, n_steps_out):
	X, y = list(), list()
	for i in range(len(sequences)):
		end_ix = i + n_steps_in
		out_end_ix = end_ix + n_steps_out
		if out_end_ix > len(sequences):
			break
		seq_x, seq_y = sequences[i:end_ix, :], sequences[end_ix:out_end_ix, :]
		X.append(seq_x)
		y.append(seq_y)
	return array(X), array(y)

scaler = MinMaxScaler()
df_scaled = scaler.fit_transform(data_fix)

total_dataset = len(data_fix)
df_train = df_scaled[:int(total_dataset*0.80)]
df_test = df_scaled[int(total_dataset*0.80):total_dataset]

print('Data for train:', df_train.shape)
print('Total hari for train:', round(df_train.shape[0]/24))
print('\nData for test:', df_test.shape)
print('Total hari for test:', round(df_test.shape[0]/24))
# Out:
# Data for train: (4665, 10)
# Total hari for train: 194
#
# Data for test: (1167, 10)
# Total hari for test: 49

# %%
#Memilih angka timestep
n_steps_in, n_steps_out = 24,1
x_train, y_train = split_sequences(df_train, n_steps_in, n_steps_out)
x_test, y_test = split_sequences(df_test, n_steps_in, n_steps_out)
n_features = x_train.shape[2]

print('Data input structure for training',x_train[0])
print('\nData output structure for validation', y_test[0])
# Out:
# Data input structure for training [[0.00000000e+00 1.65964173e-01 1.61632465e-01 3.36538462e-02
#   3.59773856e-02 0.00000000e+00 4.98845883e-01 3.41199886e-01
#   5.01638305e-01 0.00000000e+00]
#  [0.00000000e+00 1.67808219e-01 1.57020982e-01 3.36538462e-02
#   3.44354977e-02 0.00000000e+00 4.98449620e-01 3.35513221e-01
#   5.01638305e-01 0.00000000e+00]
#  [0.00000000e+00 1.69915701e-01 1.54254093e-01 3.36538462e-02
#   3.32362515e-02 0.00000000e+00 4.98201956e-01 3.38356554e-01
#   5.01638305e-01 0.00000000e+00]
#  [0.00000000e+00 1.66754478e-01 1.50795481e-01 3.84615385e-02
#   3.01524756e-02 3.05810398e-03 4.98092983e-01 3.35513221e-01
#   5.01638305e-01 0.00000000e+00]
#  [0.00000000e+00 1.66754478e-01 1.49181462e-01 3.36538462e-02
#   3.64913483e-02 8.40978593e-03 4.98102890e-01 3.37787887e-01
#   5.01638305e-01 0.00000000e+00]
#  [0.00000000e+00 1.67808219e-01 1.46414572e-01 3.84615385e-02
#   2.89532294e-02 1.52905199e-03 4.98518966e-01 3.31248223e-01
#   5.01638305e-01 0.00000000e+00]
#  [0.00000000e+00 1.68335090e-01 1.45722850e-01 3.84615385e-02
#   3.87185198e-02 7.64525994e-04 4.98826070e-01 3.34091555e-01
#   5.01638305e-01 2.10696921e-03]
#  [0.00000000e+00 1.73867229e-01 1.53331796e-01 3.36538462e-02
#   7.07555251e-02 6.11620795e-03 4.98895416e-01 3.63946545e-01
#   5.01638305e-01 1.37763371e-02]
#  [0.00000000e+00 1.73867229e-01 1.66474522e-01 3.36538462e-02
#   1.27805379e-01 1.52905199e-02 4.98925136e-01 4.06596531e-01
#   4.43610612e-01 3.33873582e-02]
#  [0.00000000e+00 5.82718651e-01 8.68111598e-01 1.25000000e-01
#   6.92821655e-01 2.44648318e-02 9.97939431e-01 8.62951379e-01
#   8.14818730e-01 9.56239870e-02]
#  [0.00000000e+00 4.50474183e-02 1.76705417e-01 4.80769231e-03
#   1.87253726e-01 2.37003058e-02 4.98855790e-01 4.50668183e-01
#   3.63915020e-01 4.03565640e-02]
#  [0.00000000e+00 4.24130664e-02 2.11205903e-01 4.80769231e-03
#   1.85883159e-01 1.75840979e-02 4.98538779e-01 4.49246517e-01
#   3.57995984e-01 3.56564019e-02]
#  [0.00000000e+00 4.24130664e-02 2.16047959e-01 0.00000000e+00
#   2.56467363e-01 3.05810398e-02 4.98152423e-01 4.63463179e-01
#   3.62012472e-01 1.31118314e-01]
#  [0.00000000e+00 4.61011591e-02 2.37952502e-01 0.00000000e+00
#   1.90680144e-01 4.96941896e-02 4.97468869e-01 4.60335513e-01
#   3.56304830e-01 3.09562399e-02]
#  [0.00000000e+00 4.24130664e-02 2.67696564e-01 0.00000000e+00
#   2.92958712e-01 5.58103976e-02 4.96765501e-01 5.06113165e-01
#   2.64242680e-01 1.06158833e-01]
#  [4.48113208e-02 1.94942044e-01 2.70002306e-01 5.28846154e-02
#   2.59037177e-01 5.42813456e-02 4.96270172e-01 4.93602502e-01
#   2.80520030e-01 2.94975689e-02]
#  [0.00000000e+00 1.13013699e-01 2.32649297e-01 3.36538462e-02
#   1.88110331e-01 4.74006116e-02 4.96200826e-01 4.70571510e-01
#   3.37702146e-01 1.60453809e-02]
#  [0.00000000e+00 9.29926238e-02 2.13742218e-01 2.88461538e-02
#   1.62926161e-01 2.98165138e-02 4.96389051e-01 4.49246517e-01
#   3.57784589e-01 7.45542950e-03]
#  [0.00000000e+00 8.40358272e-02 2.01982938e-01 2.40384615e-02
#   1.06047627e-01 9.17431193e-03 4.96715968e-01 4.10861530e-01
#   4.52383469e-01 0.00000000e+00]
#  [0.00000000e+00 8.16649104e-02 1.92990546e-01 2.40384615e-02
#   1.06047627e-01 1.07033639e-02 4.97260830e-01 4.02331533e-01
#   4.22788289e-01 0.00000000e+00]
#  [0.00000000e+00 7.69230769e-02 1.85151026e-01 2.40384615e-02
#   1.00565359e-01 2.14067278e-02 4.97904758e-01 3.93801535e-01
#   4.23950957e-01 0.00000000e+00]
#  [0.00000000e+00 7.53424658e-02 1.79617247e-01 1.92307692e-02
#   8.85728970e-02 1.37614679e-02 4.98618032e-01 3.85271538e-01
#   4.43927703e-01 0.00000000e+00]
#  [0.00000000e+00 7.24446786e-02 1.73852894e-01 1.92307692e-02
#   6.97275998e-02 7.64525994e-04 4.98489246e-01 3.72476543e-01
#   4.67181059e-01 0.00000000e+00]
#  [0.00000000e+00 7.11275026e-02 1.69471985e-01 1.92307692e-02
#   6.01336303e-02 7.64525994e-04 4.98647752e-01 3.65368212e-01
#   4.72465913e-01 0.00000000e+00]]
#
# Data output structure for validation [[0.         0.13408851 0.19045423 0.20192308 0.25218434 0.10321101
#   0.50107486 0.4122832  0.47775077 0.02382496]]

# %%
tf.keras.backend.clear_session()
# define model
model = Sequential()
model.add(LSTM(100,activation='tanh',input_shape=(n_steps_in, n_features)))
model.add(RepeatVector(n_steps_out))
model.add(LSTM(100,activation='tanh', return_sequences=True))
model.add(TimeDistributed(Dense(n_features)))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 100)               44400
#
#  repeat_vector (RepeatVecto  (None, 1, 100)            0
#  r)
#
#  lstm_1 (LSTM)               (None, 1, 100)            80400
#
#  time_distributed (TimeDist  (None, 1, 10)             1010
#  ributed)
#
# =================================================================
# Total params: 125810 (491.45 KB)
# Trainable params: 125810 (491.45 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# fit mode
epoch = 100
learning_rate = 0.005
optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)
model.compile(optimizer=optimizer, loss='mse',
              metrics=[tf.metrics.MeanAbsoluteError()])

history = model.fit(x_train, y_train, epochs=epoch, validation_data=(x_test, y_test))
# Out:
# Epoch 1/100
# 146/146 [==============================] - 8s 25ms/step - loss: 0.0047 - mean_absolute_error: 0.0390 - val_loss: 0.0012 - val_mean_absolute_error: 0.0205
# Epoch 2/100
# 146/146 [==============================] - 3s 19ms/step - loss: 0.0017 - mean_absolute_error: 0.0224 - val_loss: 0.0014 - val_mean_absolute_error: 0.0230
# Epoch 3/100
# 146/146 [==============================] - 5s 34ms/step - loss: 0.0015 - mean_absolute_error: 0.0204 - val_loss: 0.0013 - val_mean_absolute_error: 0.0249
# Epoch 4/100
# 146/146 [==============================] - 3s 19ms/step - loss: 0.0014 - mean_absolute_error: 0.0192 - val_loss: 8.4191e-04 - val_mean_absolute_error: 0.0155
# Epoch 5/100
# 146/146 [==============================] - 3s 18ms/step - loss: 0.0014 - mean_absolute_error: 0.0187 - val_loss: 8.5948e-04 - val_mean_absolute_error: 0.0163
# Epoch 6/100
# 146/146 [==============================] - 3s 19ms/step - loss: 0.0013 - mean_absolute_error: 0.0183 - val_loss: 7.9339e-04 - val_mean_absolute_error: 0.0153
# Epoch 7/100
# 146/146 [==============================] - 4s 31ms/step - loss: 0.0013 - mean_absolute_error: 0.0177 - val_loss: 8.5179e-04 - val_mean_absolute_error: 0.0166
# Epoch 8/100
# 146/146 [==============================] - 4s 26ms/step - loss: 0.0013 - mean_absolute_error: 0.0178 - val_loss: 9.7791e-04 - val_mean_absolute_error: 0.0176
# Epoch 9/100
# 146/146 [==============================] - 3s 19ms/step - loss: 0.0013 - mean_absolute_error: 0.0174 - val_loss: 0.0010 - val_mean_absolute_error: 0.0226
# Epoch 10/100
# 146/146 [==============================] - 3s 19ms/step - loss: 0.0013 - mean_absolute_error: 0.0180 - val_loss: 7.7656e-04 - val_mean_absolute_error: 0.0148
# Epoch 11/100
# 146/146 [==============================] - 3s 20ms/step - loss: 0.0012 - mean_absolute_error: 0.0171 - val_loss: 7.5242e-04 - val_mean_absolute_error: 0.0136
# Epoch 12/100
# 146/146 [==============================] - 4s 28ms/step - loss: 0.0012 - mean_absolute_error: 0.0167 - val_loss: 7.9433e-04 - val_mean_absolute_error: 0.0143
# Epoch 13/100
# 146/146 [==============================] - 3s 19ms/step - loss: 0.0012 - mean_absolute_error: 0.0171 - val_loss: 8.6428e-04 - val_mean_absolute_error: 0.0151
# Epoch 14/100
# 146/146 [==============================] - 3s 18ms/step - loss: 0.0012 - mean_absolute_error: 0.0166 - val_loss: 0.0011 - val_mean_absolute_error: 0.0200
# Epoch 15/100
# 146/146 [==============================] - 3s 19ms/step - loss: 0.0012 - mean_absolute_error: 0.0171 - val_loss: 8.2629e-04 - val_mean_absolute_error: 0.0152
# Epoch 16/100
# 146/146 [==============================] - 4s 25ms/step - loss: 0.0012 - mean_absolute_error: 0.0167 - val_loss: 8.3748e-04 - val_mean_absolute_error: 0.0155
# Epoch 17/100
# 146/146 [==============================] - 3s 20ms/step - loss: 0.0012 - mean_absolute_error: 0.0171 - val_loss: 9.6696e-04 - val_mean_absolute_error: 0.0199
# Epoch 18/100
# 146/146 [==============================] - 3s 19ms/step - loss: 0.0012 - mean_absolute_error: 0.0168 - val_loss: 9.9825e-04 - val_mean_absolute_error: 0.0190
# Epoch 19/100
# 146/146 [==============================] - 3s 19ms/step - loss: 0.0012 - mean_absolute_error: 0.0163 - val_loss: 7.8275e-04 - val_mean_absolute_error: 0.0151
# Epoch 20/100
# 146/146 [==============================] - 3s 21ms/step - loss: 0.0012 - mean_absolute_error: 0.0162 - val_loss: 8.1167e-04 - val_mean_absolute_error: 0.0166
# Epoch 21/100
# 146/146 [==============================] - 4s 27ms/step - loss: 0.0012 - mean_absolute_error: 0.0169 - val_loss: 9.2471e-04 - val_mean_absolute_error: 0.0176
# Epoch 22/100
# 146/146 [==============================] - 3s 19ms/step - loss: 0.0012 - mean_absolute_error: 0.0166 - val_loss: 8.9109e-04 - val_mean_absolute_error: 0.0182
# Epoch 23/100
# 146/146 [==============================] - 3s 19ms/step - loss: 0.0012 - mean_absolute_error: 0.0165 - val_loss: 7.7524e-04 - val_mean_absolute_error: 0.0138
# Epoch 24/100
# 146/146 [==============================] - 3s 19ms/step - loss: 0.0011 - mean_absolute_error: 0.0160 - val_loss: 8.4960e-04 - val_mean_absolute_error: 0.0167
# Epoch 25/100
# 146/146 [==============================] - 4s 26ms/step - loss: 0.0012 - mean_absolute_error: 0.0165 - val_loss: 7.9973e-04 - val_mean_absolute_error: 0.0154
# Epoch 26/100
# 146/146 [==============================] - 3s 20ms/step - loss: 0.0011 - mean_absolute_error: 0.0158 - val_loss: 7.9005e-04 - val_mean_absolute_error: 0.0154
# Epoch 27/100
# 146/146 [==============================] - 3s 19ms/step - loss: 0.0011 - mean_absolute_error: 0.0160 - val_loss: 7.8454e-04 - val_mean_absolute_error: 0.0144
# Epoch 28/100
# 146/146 [==============================] - 3s 19ms/step - loss: 0.0011 - mean_absolute_error: 0.0161 - val_loss: 9.1466e-04 - val_mean_absolute_error: 0.0198
# Epoch 29/100
# 146/146 [==============================] - 3s 22ms/step - loss: 0.0012 - mean_absolute_error: 0.0166 - val_loss: 7.9306e-04 - val_mean_absolute_error: 0.0151
# Epoch 30/100
# 146/146 [==============================] - 4s 26ms/step - loss: 0.0011 - mean_absolute_error: 0.0163 - val_loss: 8.6518e-04 - val_mean_absolute_error: 0.0172
# Epoch 31/100
# 146/146 [==============================] - 3s 19ms/step - loss: 0.0011 - mean_absolute_error: 0.0162 - val_loss: 8.1493e-04 - val_mean_absolute_error: 0.0161
# Epoch 32/100
# 146/146 [==============================] - 3s 19ms/step - loss: 0.0011 - mean_absolute_error: 0.0155 - val_loss: 7.6201e-04 - val_mean_absolute_error: 0.0138
# Epoch 33/100
# 146/146 [==============================] - 3s 19ms/step - loss: 0.0011 - mean_absolute_error: 0.0160 - val_loss: 7.6500e-04 - val_mean_absolute_error: 0.0138
# Epoch 34/100
# 146/146 [==============================] - 4s 27ms/step - loss: 0.0011 - mean_absolute_error: 0.0157 - val_loss: 7.5302e-04 - val_mean_absolute_error: 0.0141
# Epoch 35/100
# 146/146 [==============================] - 3s 20ms/step - loss: 0.0011 - mean_absolute_error: 0.0156 - val_loss: 7.6457e-04 - val_mean_absolute_error: 0.0147
# Epoch 36/100
# 146/146 [==============================] - 3s 19ms/step - loss: 0.0011 - mean_absolute_error: 0.0154 - val_loss: 8.3188e-04 - val_mean_absolute_error: 0.0172
# Epoch 37/100
# 146/146 [==============================] - 3s 19ms/step - loss: 0.0011 - mean_absolute_error: 0.0156 - val_loss: 7.4935e-04 - val_mean_absolute_error: 0.0150
# Epoch 38/100
# 146/146 [==============================] - 3s 21ms/step - loss: 0.0011 - mean_absolute_error: 0.0157 - val_loss: 7.3012e-04 - val_mean_absolute_error: 0.0138
# Epoch 39/100
# 146/146 [==============================] - 4s 26ms/step - loss: 0.0011 - mean_absolute_error: 0.0153 - val_loss: 8.6650e-04 - val_mean_absolute_error: 0.0166
# Epoch 40/100
# 146/146 [==============================] - 3s 19ms/step - loss: 0.0011 - mean_absolute_error: 0.0163 - val_loss: 7.4951e-04 - val_mean_absolute_error: 0.0137
# Epoch 41/100
# 146/146 [==============================] - 3s 19ms/step - loss: 0.0011 - mean_absolute_error: 0.0158 - val_loss: 7.9363e-04 - val_mean_absolute_error: 0.0146
# Epoch 42/100
# 146/146 [==============================] - 3s 19ms/step - loss: 0.0011 - mean_absolute_error: 0.0157 - val_loss: 8.4007e-04 - val_mean_absolute_error: 0.0156
# Epoch 43/100
# 146/146 [==============================] - 4s 29ms/step - loss: 0.0011 - mean_absolute_error: 0.0154 - val_loss: 7.6001e-04 - val_mean_absolute_error: 0.0154
# Epoch 44/100
# 146/146 [==============================] - 3s 19ms/step - loss: 0.0011 - mean_absolute_error: 0.0152 - val_loss: 8.1324e-04 - val_mean_absolute_error: 0.0169
# Epoch 45/100
# 146/146 [==============================] - 3s 19ms/step - loss: 0.0010 - mean_absolute_error: 0.0153 - val_loss: 9.4261e-04 - val_mean_absolute_error: 0.0195
# Epoch 46/100
# 146/146 [==============================] - 3s 19ms/step - loss: 0.0011 - mean_absolute_error: 0.0160 - val_loss: 7.7005e-04 - val_mean_absolute_error: 0.0137
# Epoch 47/100
# 146/146 [==============================] - 3s 22ms/step - loss: 0.0010 - mean_absolute_error: 0.0153 - val_loss: 7.5448e-04 - val_mean_absolute_error: 0.0140
# Epoch 48/100
# 146/146 [==============================] - 4s 25ms/step - loss: 0.0010 - mean_absolute_error: 0.0153 - val_loss: 7.5607e-04 - val_mean_absolute_error: 0.0137
# Epoch 49/100
# 146/146 [==============================] - 3s 19ms/step - loss: 0.0010 - mean_absolute_error: 0.0153 - val_loss: 0.0013 - val_mean_absolute_error: 0.0222
# Epoch 50/100
# 146/146 [==============================] - 3s 19ms/step - loss: 0.0011 - mean_absolute_error: 0.0165 - val_loss: 7.8014e-04 - val_mean_absolute_error: 0.0146
# Epoch 51/100
# 146/146 [==============================] - 3s 19ms/step - loss: 0.0010 - mean_absolute_error: 0.0152 - val_loss: 7.4240e-04 - val_mean_absolute_error: 0.0137
# Epoch 52/100
# 146/146 [==============================] - 4s 29ms/step - loss: 0.0010 - mean_absolute_error: 0.0151 - val_loss: 7.8310e-04 - val_mean_absolute_error: 0.0138
# Epoch 53/100
# 146/146 [==============================] - 3s 20ms/step - loss: 9.6969e-04 - mean_absolute_error: 0.0149 - val_loss: 7.7154e-04 - val_mean_absolute_error: 0.0150
# Epoch 54/100
# 146/146 [==============================] - 3s 20ms/step - loss: 0.0010 - mean_absolute_error: 0.0152 - val_loss: 7.2726e-04 - val_mean_absolute_error: 0.0127
# Epoch 55/100
# 146/146 [==============================] - 3s 19ms/step - loss: 9.9870e-04 - mean_absolute_error: 0.0152 - val_loss: 7.7250e-04 - val_mean_absolute_error: 0.0145
# Epoch 56/100
# 146/146 [==============================] - 4s 24ms/step - loss: 0.0011 - mean_absolute_error: 0.0156 - val_loss: 8.0050e-04 - val_mean_absolute_error: 0.0160
# Epoch 57/100
# 146/146 [==============================] - 4s 24ms/step - loss: 0.0010 - mean_absolute_error: 0.0150 - val_loss: 7.9957e-04 - val_mean_absolute_error: 0.0159
# Epoch 58/100
# 146/146 [==============================] - 3s 19ms/step - loss: 0.0010 - mean_absolute_error: 0.0149 - val_loss: 8.2462e-04 - val_mean_absolute_error: 0.0152
# Epoch 59/100
# 146/146 [==============================] - 3s 20ms/step - loss: 0.0010 - mean_absolute_error: 0.0150 - val_loss: 7.5131e-04 - val_mean_absolute_error: 0.0143
# Epoch 60/100
# 146/146 [==============================] - 3s 19ms/step - loss: 9.7543e-04 - mean_absolute_error: 0.0147 - val_loss: 7.3802e-04 - val_mean_absolute_error: 0.0136
# Epoch 61/100
# 146/146 [==============================] - 4s 28ms/step - loss: 9.6822e-04 - mean_absolute_error: 0.0147 - val_loss: 7.9282e-04 - val_mean_absolute_error: 0.0149
# Epoch 62/100
# 146/146 [==============================] - 3s 19ms/step - loss: 9.2889e-04 - mean_absolute_error: 0.0143 - val_loss: 8.4618e-04 - val_mean_absolute_error: 0.0163
# Epoch 63/100
# 146/146 [==============================] - 3s 19ms/step - loss: 9.5836e-04 - mean_absolute_error: 0.0150 - val_loss: 7.8107e-04 - val_mean_absolute_error: 0.0147
# Epoch 64/100
# 146/146 [==============================] - 3s 19ms/step - loss: 9.3585e-04 - mean_absolute_error: 0.0148 - val_loss: 7.4839e-04 - val_mean_absolute_error: 0.0152
# Epoch 65/100
# 146/146 [==============================] - 4s 27ms/step - loss: 9.4650e-04 - mean_absolute_error: 0.0151 - val_loss: 7.7716e-04 - val_mean_absolute_error: 0.0151
# Epoch 66/100
# 146/146 [==============================] - 3s 20ms/step - loss: 9.5291e-04 - mean_absolute_error: 0.0153 - val_loss: 7.4460e-04 - val_mean_absolute_error: 0.0136
# Epoch 67/100
# 146/146 [==============================] - 3s 20ms/step - loss: 9.3895e-04 - mean_absolute_error: 0.0151 - val_loss: 7.5796e-04 - val_mean_absolute_error: 0.0144
# Epoch 68/100
# 146/146 [==============================] - 3s 19ms/step - loss: 9.5967e-04 - mean_absolute_error: 0.0149 - val_loss: 8.0486e-04 - val_mean_absolute_error: 0.0144
# Epoch 69/100
# 146/146 [==============================] - 3s 23ms/step - loss: 9.6322e-04 - mean_absolute_error: 0.0149 - val_loss: 7.3920e-04 - val_mean_absolute_error: 0.0142
# Epoch 70/100
# 146/146 [==============================] - 4s 26ms/step - loss: 9.1721e-04 - mean_absolute_error: 0.0146 - val_loss: 7.3514e-04 - val_mean_absolute_error: 0.0147
# Epoch 71/100
# 146/146 [==============================] - 3s 20ms/step - loss: 9.1060e-04 - mean_absolute_error: 0.0147 - val_loss: 7.8410e-04 - val_mean_absolute_error: 0.0147
# Epoch 72/100
# 146/146 [==============================] - 3s 19ms/step - loss: 8.9328e-04 - mean_absolute_error: 0.0145 - val_loss: 7.9741e-04 - val_mean_absolute_error: 0.0169
# Epoch 73/100
# 146/146 [==============================] - 3s 19ms/step - loss: 9.1351e-04 - mean_absolute_error: 0.0151 - val_loss: 7.0638e-04 - val_mean_absolute_error: 0.0132
# Epoch 74/100
# 146/146 [==============================] - 4s 29ms/step - loss: 8.6955e-04 - mean_absolute_error: 0.0145 - val_loss: 7.1763e-04 - val_mean_absolute_error: 0.0137
# Epoch 75/100
# 146/146 [==============================] - 3s 19ms/step - loss: 9.1744e-04 - mean_absolute_error: 0.0149 - val_loss: 7.9738e-04 - val_mean_absolute_error: 0.0148
# Epoch 76/100
# 146/146 [==============================] - 3s 20ms/step - loss: 9.5844e-04 - mean_absolute_error: 0.0148 - val_loss: 7.2792e-04 - val_mean_absolute_error: 0.0137
# Epoch 77/100
# 146/146 [==============================] - 3s 19ms/step - loss: 8.9163e-04 - mean_absolute_error: 0.0145 - val_loss: 8.6545e-04 - val_mean_absolute_error: 0.0157
# Epoch 78/100
# 146/146 [==============================] - 3s 24ms/step - loss: 8.5234e-04 - mean_absolute_error: 0.0146 - val_loss: 7.5830e-04 - val_mean_absolute_error: 0.0149
# Epoch 79/100
# 146/146 [==============================] - 3s 24ms/step - loss: 8.8090e-04 - mean_absolute_error: 0.0148 - val_loss: 7.9597e-04 - val_mean_absolute_error: 0.0147
# Epoch 80/100
# 146/146 [==============================] - 3s 19ms/step - loss: 9.2031e-04 - mean_absolute_error: 0.0148 - val_loss: 7.3318e-04 - val_mean_absolute_error: 0.0140
# Epoch 81/100
# 146/146 [==============================] - 3s 20ms/step - loss: 8.8479e-04 - mean_absolute_error: 0.0143 - val_loss: 8.3720e-04 - val_mean_absolute_error: 0.0151
# Epoch 82/100
# 146/146 [==============================] - 3s 20ms/step - loss: 8.9999e-04 - mean_absolute_error: 0.0142 - val_loss: 7.0963e-04 - val_mean_absolute_error: 0.0130
# Epoch 83/100
# 146/146 [==============================] - 4s 29ms/step - loss: 8.3380e-04 - mean_absolute_error: 0.0139 - val_loss: 7.2787e-04 - val_mean_absolute_error: 0.0135
# Epoch 84/100
# 146/146 [==============================] - 3s 19ms/step - loss: 8.2032e-04 - mean_absolute_error: 0.0138 - val_loss: 7.7592e-04 - val_mean_absolute_error: 0.0146
# Epoch 85/100
# 146/146 [==============================] - 3s 19ms/step - loss: 8.1244e-04 - mean_absolute_error: 0.0139 - val_loss: 8.2693e-04 - val_mean_absolute_error: 0.0157
# Epoch 86/100
# 146/146 [==============================] - 3s 19ms/step - loss: 8.1176e-04 - mean_absolute_error: 0.0141 - val_loss: 8.2513e-04 - val_mean_absolute_error: 0.0157
# Epoch 87/100
# 146/146 [==============================] - 4s 24ms/step - loss: 8.6526e-04 - mean_absolute_error: 0.0146 - val_loss: 7.4083e-04 - val_mean_absolute_error: 0.0140
# Epoch 88/100
# 146/146 [==============================] - 4s 24ms/step - loss: 8.1903e-04 - mean_absolute_error: 0.0141 - val_loss: 7.7676e-04 - val_mean_absolute_error: 0.0151
# Epoch 89/100
# 146/146 [==============================] - 3s 20ms/step - loss: 8.2908e-04 - mean_absolute_error: 0.0144 - val_loss: 7.6238e-04 - val_mean_absolute_error: 0.0149
# Epoch 90/100
# 146/146 [==============================] - 3s 19ms/step - loss: 8.2060e-04 - mean_absolute_error: 0.0143 - val_loss: 7.6597e-04 - val_mean_absolute_error: 0.0148
# Epoch 91/100
# 146/146 [==============================] - 3s 20ms/step - loss: 7.9626e-04 - mean_absolute_error: 0.0142 - val_loss: 7.5182e-04 - val_mean_absolute_error: 0.0140
# Epoch 92/100
# 146/146 [==============================] - 4s 28ms/step - loss: 7.7198e-04 - mean_absolute_error: 0.0139 - val_loss: 8.2525e-04 - val_mean_absolute_error: 0.0153
# Epoch 93/100
# 146/146 [==============================] - 3s 20ms/step - loss: 7.9391e-04 - mean_absolute_error: 0.0141 - val_loss: 8.4557e-04 - val_mean_absolute_error: 0.0161
# Epoch 94/100
# 146/146 [==============================] - 3s 19ms/step - loss: 8.4838e-04 - mean_absolute_error: 0.0148 - val_loss: 7.3937e-04 - val_mean_absolute_error: 0.0142
# Epoch 95/100
# 146/146 [==============================] - 3s 20ms/step - loss: 8.1398e-04 - mean_absolute_error: 0.0141 - val_loss: 7.4378e-04 - val_mean_absolute_error: 0.0138
# Epoch 96/100
# 146/146 [==============================] - 4s 27ms/step - loss: 7.8696e-04 - mean_absolute_error: 0.0137 - val_loss: 8.0550e-04 - val_mean_absolute_error: 0.0173
# Epoch 97/100
# 146/146 [==============================] - 3s 21ms/step - loss: 7.8067e-04 - mean_absolute_error: 0.0140 - val_loss: 7.3526e-04 - val_mean_absolute_error: 0.0152
# Epoch 98/100
# 146/146 [==============================] - 4s 29ms/step - loss: 7.4965e-04 - mean_absolute_error: 0.0137 - val_loss: 7.1690e-04 - val_mean_absolute_error: 0.0141
# Epoch 99/100
# 146/146 [==============================] - 3s 20ms/step - loss: 7.4652e-04 - mean_absolute_error: 0.0136 - val_loss: 7.1142e-04 - val_mean_absolute_error: 0.0139
# Epoch 100/100
# 146/146 [==============================] - 5s 31ms/step - loss: 7.4975e-04 - mean_absolute_error: 0.0136 - val_loss: 7.7914e-04 - val_mean_absolute_error: 0.0145

# %%
# Mendapatkan nilai kerugian dan metrik dari objek history
train_loss = history.history['loss']
val_loss = history.history['val_loss']

# Membuat plot kurva kerugian
plt.plot(train_loss, label='Training Loss')
plt.plot(val_loss, label='validation loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
prediksi = model.predict(x_test)
print(prediksi.shape)
print(y_test.shape)
# Out:
# 36/36 [==============================] - 1s 7ms/step
# (1143, 1, 10)
# (1143, 1, 10)

# %%
#reshape
prediksi = np.reshape(prediksi, (1143*1, 10))
real = np.reshape(y_test, (1143*1, 10))

# rescale
prediksi = pd.DataFrame(prediksi)
prediksi = scaler.inverse_transform(prediksi)
prediksi = pd.DataFrame(prediksi)
prediksi = prediksi.rename(columns={0: "RF", 1: "SM", 2: "ST",
                                          3: "SEC", 4: "BLT", 5: "WS",
                                          6:"AP", 7:"AT", 8:"AH", 9:"UV"})

real = pd.DataFrame(real)
real = scaler.inverse_transform(real)
real = pd.DataFrame(real)

print(prediksi.shape)
print(real.shape)
# Out:
# (1143, 10)
# (1143, 10)

# %%
df_t = df_time[int(len(data_fix)*0.8) : ]
df_t1 = df_t[4:]
df_akhir = pd.DataFrame()

indicators = ['RF_LSTM','SM_LSTM','ST_LSTM','SEC_LSTM','BLT_LSTM','WS_LSTM','AP_LSTM','AT_LSTM','AH_LSTM','UV_LSTM']
m=-1
for i in indicator:
  m=m+1
  df_akhir[i] = real[m]
  df_akhir[indicators[m]] = prediksi[i]

df_akhir["waktu"] = df_akhir.RF
for i in range(0,len(df_akhir)):
   df_akhir.waktu.iloc[i] = df_t1.iloc[i]
df_akhir = df_akhir.set_index('waktu')
df_akhir
# Out:
# <ipython-input-44-1b243773ce7b>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_akhir.waktu.iloc[i] = df_t1.iloc[i]
#                       RF   RF_LSTM     SM    SM_LSTM     ST    ST_LSTM   SEC  \
# waktu
# 2023-06-13 13:00:00  0.0 -0.041301  24.30  24.434284  29.95  30.106682  66.0
# 2023-06-13 14:00:00  0.0 -0.065186  19.40  24.313425  23.93  29.828753  52.8
# 2023-06-13 15:00:00  0.0 -0.302124  24.26  24.220594  29.91  30.267410  66.0
# 2023-06-13 16:00:00  0.0 -0.776951  19.44  24.752684  24.01  30.297188  52.8
# 2023-06-13 17:00:00  0.0 -0.117646  24.30  25.100456  30.15  31.155994  66.0
# ...                  ...       ...    ...        ...    ...        ...   ...
# 2023-07-30 23:00:00  0.0 -0.014932  26.94  26.818445  29.50  29.165005  79.0
# 2023-07-31 00:00:00  0.0 -0.145440  26.98  26.685432  29.46  29.189823  79.0
# 2023-07-31 01:00:00  0.0 -0.235200  26.89  26.547022  29.40  29.098152  79.0
# 2023-07-31 02:00:00  0.0  0.041691  26.94  26.681026  29.30  28.982815  80.0
# 2023-07-31 03:00:00  0.0  0.017092  26.88  26.782021  29.21  28.793987  79.0
#
#                       SEC_LSTM    BLT   BLT_LSTM    WS   WS_LSTM       AP  \
# waktu
# 2023-06-13 13:00:00  66.545731  36.70  32.818790  1.35  0.818375  1011.60
# 2023-06-13 14:00:00  65.834930  44.74  38.563744  1.62  1.613138  1011.22
# 2023-06-13 15:00:00  62.169731  38.51  46.817890  1.28  1.911363  1010.78
# 2023-06-13 16:00:00  66.801659  39.89  42.700443  1.10  1.598127  1009.90
# 2023-06-13 17:00:00  65.881218  37.85  39.868137  0.96  1.835090  1009.26
# ...                        ...    ...        ...   ...       ...      ...
# 2023-07-30 23:00:00  79.866722  26.30  26.972544  1.03  1.366662  1009.80
# 2023-07-31 00:00:00  79.059517  25.00  26.114925  0.08  0.658176  1010.70
# 2023-07-31 01:00:00  78.154846  24.48  25.832113  0.07  0.280461  1011.50
# 2023-07-31 02:00:00  78.668076  23.92  25.541616  0.03  0.296975  1011.70
# 2023-07-31 03:00:00  79.260399  23.73  24.942261  0.08  0.190569  1011.76
#
#                          AP_LSTM     AT    AT_LSTM     AH    AH_LSTM    UV  \
# waktu
# 2023-06-13 13:00:00  1010.971924  29.00  27.817987  90.40  91.954811  1.47
# 2023-06-13 14:00:00  1011.037659  30.40  30.167816  82.18  84.663857  2.79
# 2023-06-13 15:00:00  1018.725281  30.62  32.745983  79.50  75.734360  2.55
# 2023-06-13 16:00:00  1026.655151  31.50  33.108334  75.52  78.582687  3.05
# 2023-06-13 17:00:00  1011.397583  31.84  31.936979  75.84  74.928772  2.00
# ...                          ...    ...        ...    ...        ...   ...
# 2023-07-30 23:00:00  1003.514343  26.18  26.539061  93.00  88.005547  0.00
# 2023-07-31 00:00:00  1003.625793  25.10  25.607124  94.92  91.262695  0.00
# 2023-07-31 01:00:00  1005.807983  24.10  24.942831  94.92  93.005966  0.00
# 2023-07-31 02:00:00  1004.857056  23.70  24.315338  94.92  93.441658  0.00
# 2023-07-31 03:00:00  1003.985840  23.30  23.873404  94.92  93.388367  0.00
#
#                       UV_LSTM
# waktu
# 2023-06-13 13:00:00  0.715160
# 2023-06-13 14:00:00  1.115952
# 2023-06-13 15:00:00  2.162271
# 2023-06-13 16:00:00  4.006381
# 2023-06-13 17:00:00  2.865801
# ...                       ...
# 2023-07-30 23:00:00 -0.230645
# 2023-07-31 00:00:00 -0.373584
# 2023-07-31 01:00:00 -0.308160
# 2023-07-31 02:00:00 -0.264664
# 2023-07-31 03:00:00 -0.256568
#
# [1143 rows x 20 columns]

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl

fig, axes = plt.subplots(4, 3, figsize=(14, 6))
fig = mpl.pyplot.gcf()
mpl.rcParams['axes.grid'] = False
plt.rcParams.update({
    "font.size": 9,
})

df_akhir[['RF','RF_LSTM']].plot(ax=axes[0, 0])
df_akhir[['SM', 'SM_LSTM']].plot(ax=axes[0, 1])
df_akhir[['ST', 'ST_LSTM']].plot(ax=axes[0, 2])
df_akhir[['SEC', 'SEC_LSTM']].plot(ax=axes[1, 0])
df_akhir[['BLT', 'BLT_LSTM']].plot(ax=axes[1, 1])
df_akhir[['WS', 'WS_LSTM']].plot(ax=axes[1, 2])
df_akhir[['AP', 'AP_LSTM']].plot(ax=axes[2, 0])
df_akhir[['AT', 'AT_LSTM']].plot(ax=axes[2, 1])
df_akhir[['AH', 'AH_LSTM']].plot(ax=axes[2, 2])
df_akhir[['UV', 'UV_LSTM']].plot(ax=axes[3, 0])

# Jika Anda hanya memiliki 7 variabel, maka subplot (1,3) tidak digunakan
# Hapus subplot (1,3)
fig.delaxes(axes[3, 1])
fig.delaxes(axes[3, 2])

plt.show()

# %%
data_prediksi = df_akhir
data_prediksi.to_excel('Hasil Prediksi Cuaca.xlsx', index =True)

# %%
for i in indicator:
  rmse = mean_squared_error(df_akhir[f'{i}'],df_akhir[f'{i}_LSTM'], squared=False)
  print(f'{i} ----> RMSE: {rmse}\n')
# Out:
# RF ----> RMSE: 1.7816374844106135
#
# SM ----> RMSE: 1.534328634518741
#
# ST ----> RMSE: 1.5119797374011756
#
# SEC ----> RMSE: 6.73351114454236
#
# BLT ----> RMSE: 2.2025318506423157
#
# WS ----> RMSE: 0.43347630078959165
#
# AP ----> RMSE: 13.51883155871371
#
# AT ----> RMSE: 1.090811935051493
#
# AH ----> RMSE: 3.693637806924551
#
# UV ----> RMSE: 1.0030938377531404

# %%
model.save_weights('./checkpoints/my_checkpoint')

# %%
# !mkdir -p saved_model
model.save('saved_model/my_model')
model.save('model_fix.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
